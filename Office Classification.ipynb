# %%
import numpy as np
import pandas as pd
import os
import sklearn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Reading Data

# %%
raw_dataset = pd.read_csv('office_data.csv')
raw_dataset
# Out:
#           id  season  episode  scene  \
# 0          1       1        1      1
# 1          2       1        1      1
# 2          3       1        1      1
# 3          4       1        1      1
# 4          5       1        1      1
# 5          6       1        1      2
# 6          7       1        1      3
# 7          8       1        1      3
# 8          9       1        1      3
# 9         10       1        1      3
# 10        11       1        1      3
# 11        12       1        1      3
# 12        13       1        1      3
# 13        14       1        1      3
# 14        15       1        1      3
# 15        16       1        1      4
# 16        17       1        1      5
# 17        18       1        1      6
# 18        19       1        1      7
# 19        20       1        1      7
# 20        21       1        1      7
# 21        22       1        1      7
# 22        23       1        1      7
# 23        24       1        1      7
# 24        25       1        1      7
# 25        26       1        1      7
# 26        27       1        1      7
# 27        28       1        1      7
# 28        29       1        1      7
# 29        30       1        1      8
# ...      ...     ...      ...    ...
# 59879  59880       9       23     99
# 59880  59881       9       23    100
# 59881  59882       9       23    101
# 59882  59883       9       23    101
# 59883  59884       9       23    101
# 59884  59885       9       23    101
# 59885  59886       9       23    102
# 59886  59887       9       23    103
# 59887  59888       9       23    104
# 59888  59889       9       23    105
# 59889  59890       9       23    106
# 59890  59891       9       23    107
# 59891  59892       9       23    107
# 59892  59893       9       23    107
# 59893  59894       9       23    107
# 59894  59895       9       23    107
# 59895  59896       9       23    108
# 59896  59897       9       23    108
# 59897  59898       9       23    108
# 59898  59899       9       23    108
# 59899  59900       9       23    108
# 59900  59901       9       23    108
# 59901  59902       9       23    109
# 59902  59903       9       23    110
# 59903  59904       9       23    111
# 59904  59905       9       23    112
# 59905  59906       9       23    113
# 59906  59907       9       23    114
# 59907  59908       9       23    115
# 59908  59909       9       23    116
#
#                                                line_text   speaker  deleted
# 0      All right Jim. Your quarterlies look very good...   Michael    False
# 1             Oh, I told you. I couldn't close it. So...       Jim    False
# 2      So you've come to the master for guidance? Is ...   Michael    False
# 3             Actually, you called me in here, but yeah.       Jim    False
# 4        All right. Well, let me show you how it's done.   Michael    False
# 5      [on the phone] Yes, I'd like to speak to your ...   Michael    False
# 6      I've, uh, I've been at Dunder Mifflin for 12 y...   Michael    False
# 7                                    Well. I don't know.       Pam    False
# 8      If you think she's cute now, you should have s...   Michael    False
# 9                                                  What?       Pam    False
# 10                                         Any messages?   Michael    False
# 11                                 Uh, yeah. Just a fax.       Pam    False
# 12     Oh! Pam, this is from Corporate. How many time...   Michael    False
# 13                                  You haven't told me.       Pam    False
# 14     It's called the wastepaper basket! Look at tha...   Michael    False
# 15     People say I am the best boss. They go, 'God w...   Michael    False
# 16     [singing] Shall I play for you? Pa rum pump um...    Dwight    False
# 17     My job is to speak to clients on the phone abo...       Jim    False
# 18                                              Whassup!   Michael    False
# 19         Whassup! I still love that after seven years.       Jim    False
# 20                                              Whassup!   Michael    False
# 21                                              Whassup!    Dwight    False
# 22                                           Whass...up!   Michael    False
# 23                                              Whassup.    Dwight    False
# 24                               [Strains, grunts] What?   Michael    False
# 25                                              Nothing.       Jim    False
# 26                         OK. All right. See you later.   Michael    False
# 27                                 All right. Take care.       Jim    False
# 28                                         Back to work.   Michael    False
# 29     [on her cell phone] Just before lunch. That wo...       Jan    False
# ...                                                  ...       ...      ...
# 59879                                       There it is.       Jim    False
# 59880  Do I get along with my co-workers? Well, first...    Dwight    False
# 59881  [on computer] You might feel sorry for me but ...      Andy    False
# 59882                                           Oh, Yes!     Kevin    False
# 59883                           You did good. Real good.    Darryl    False
# 59884                               Thanks Dad���Darryl.      Andy    False
# 59885  I spent so much of my time here at Dunder Miff...      Andy    False
# 59886  You take something ordinary, like a piece of p...     Oscar    False
# 59887  [walking out of the bathroom discovered by all...     Creed    False
# 59888  [playing guitar and singing] I saw a friend to...     Creed    False
# 59889  Imagine going back and watching a tape of your...       Jim    False
# 59890  Hey, Jim, remember flonkerton when you did Off...   Phyllis    False
# 59891                                       Thanks Phyl.       Jim    False
# 59892                   I still have my medal from that.     Creed    False
# 59893                       Do you even have a mattress?    Angela    False
# 59894           No, but I still have my medal from that.     Creed    False
# 59895          Oscar. Oscar. [crying] I think I���m gay.     Kevin    False
# 59896                               Why do you say that?     Oscar    False
# 59897    [sniffles] It���s just that I���m so emotional.     Kevin    False
# 59898      Yeah, but you���re not gay. You���re not gay.     Oscar    False
# 59899                        No, but maybe the reason���     Kevin    False
# 59900                                  You���re not gay.     Oscar    False
# 59901  [still playing and singing] And all the faces ...     Creed    False
# 59902  How did you do it? How did you capture what it...      Erin    False
# 59903  Everyday when I came into work, all I wanted t...    Darryl    False
# 59904  It all seems so very arbitrary. I applied for ...     Creed    False
# 59905  I just feel lucky that I got a chance to share...  Meredith    False
# 59906  I���m happy that this was all filmed so I can ...   Phyllis    False
# 59907  I sold paper at this company for 12 years. My ...       Jim    False
# 59908  I thought it was weird when you picked us to m...       Pam    False
#
# [59909 rows x 7 columns]

# %%
#Create a dataframe containing the counts of each word in each line
raw_dataset['speaker'].unique()
# Out:
# array(['Michael', 'Jim', 'Pam', 'Dwight', 'Jan', 'Michel', 'Todd Packer',
#        'Phyllis', 'Stanley', 'Oscar', 'Angela', 'Kevin', 'Ryan', 'Man',
#        'Roy', 'Documentary Crew Member', 'Mr. Brown', 'Toby', 'Kelly',
#        'Meredith', 'Travel Agent', 'Man on Phone', 'Everybody', 'Lonny',
#        'Darryl', 'Teammates', 'Michael and Dwight', 'Warehouse worker',
#        'Madge', 'Worker', 'Packer', 'Warehouse Worker', 'Katy',
#        'Guy at bar', 'Other Guy at Bar', 'Guy At Bar', 'Pam and Jim',
#        'Employee', "Chili's Employee", 'Waitress', 'Manager',
#        "Kevin's computer", 'Warehouse Guy', 'Warehouse guy',
#        'Warehouse guys', 'Video', 'Man in Video', 'Actor',
#        'Redheaded Actress', "Mr. O'Malley", 'Albiny', "Pam's Mom", 'Carol',
#        'Bill', 'Everyone', 'Crowd', 'song', 'Song', 'Dwight and Michael',
#        'Sherri', 'Creed', 'Devon', 'Children', 'Kid',
#        'Vance Refrigeration Worker #1', 'Vance Refrigeration Worker #2',
#        'Hank the Security Guard', 'Ira', "Ryan's Voicemail", 'Master',
#        'Alyssa', 'Christian', 'Hostess', 'Michael and Christian',
#        'Sadiq (IT guy)', 'Mark', 'Improv Teacher', 'Mary-Beth',
#        'Girl acting Pregnant', 'Actress', 'Michael and Jim',
#        'Kevin & Oscar', 'All', 'Liquor Store Clerk', 'JIm', 'Bob Vance',
#        'Phyllis, Meredith, Michael, Kevin', 'Captain Jack', 'Brenda',
#        'Darryl and Katy', 'Jim and Pam', 'Billy Merchant', 'Doctor',
#        'Lab Tech', 'Dana', "Hooter's Girls", 'Phylis', 'Gil',
#        'Pam and others', 'Ed', 'Todd', "Jim's voicemail", 'Women', 'Guy',
#        'Men', 'Group chant', 'All the Men', 'Dwight and Roy',
#        'Delivery man', 'Craig', 'Josh', 'David', 'Dan', 'Receptionist',
#        'Overhead', 'Speaker', 'Jim and Dwight', 'Melissa', 'Sasha', 'Abby',
#        'Jake', 'The Kids', 'Kids', 'Miss Trudy', 'Edward R. Meow', 'Chet',
#        'Young Michael', 'Delivery Woman', 'Delivery Boy', 'Office Staff',
#        'Store Employee', 'Pam/Jim', 'Linda', 'Hank', 'Sheriff',
#        'I.D. Photographer', 'Photographer', 'Anglea', 'Female worker',
#        "Billy's Girlfriend", 'Billy', 'Dealer', 'Bob', "Meredith's Vet",
#        'Andy', 'Karen', 'Jerome Bettis', 'Ted', 'Waiter',
#        'Jim, Josh, and Dwight', 'Evan', 'Alan', 'Ryan and others',
#        'Hannah', 'Announcer', 'Pretzel guy', 'Cousin Mose', 'Tony',
#        'Server', 'Girls', "Kelly's Mom", "Kelly's Father", 'Young Man',
#        'Andy and Jim', 'Mrs. Kapoor', 'Mr. Kapoor', 'Dwight ', 'M ichael',
#        'Michael ', 'Dwight:', 'Martin', 'Male voice', 'Michael & Dwight',
#        'Andy & Michael', 'Chef', 'Woman at bar', 'Cindy', 'Second Cindy',
#        'Other waitress', 'Andy and Michael', 'Both', 'Someone', 'Harvey',
#        'Buyer', 'Kenny', 'Julius', 'Phone', 'Staples Guy', 'MIchael',
#        'Lady', 'Paris', 'Marcy', 'Ben Franklin', 'Elizabeth', 'Priest',
#        'Uncle Al', 'Randy', 'Unknown', 'College Student',
#        'Business Student #1', 'Business Student #2', 'Business Student #3',
#        'Woman', 'Artist', 'Student 1', 'Student 2', 'Student 3', 'Rachel',
#        'Dan Gore', 'Bartender', 'Child', 'Hunter', 'Darry', 'Micheal',
#        'Larry', 'Chad Lite', 'Jamie', 'Barbara', 'School Official',
#        'Barbara Allen', 'Spanish Teacher', 'Denise', 'Group',
#        'IT Tech Guy', 'Nurse', 'Intern', 'Pediatrician', 'Robert Dunder',
#        'Amy', 'GPS', 'Larry Myers', 'Ex-client', 'Voice of Thomas Dean',
#        'sAndy', 'DunMiff/sys', 'DwightKSchrute', 'Tech Guy', 'Angels',
#        'Pizza guy', 'Voice #1 on phone', 'Voice #2 on phone', 'Micahel',
#        'Michae', 'Nick', 'Mose', 'Co-Worker 1', 'Stanely', 'Micael',
#        'Vikram', 'Co-Worker 2', 'Co-Worker 3', 'Mr. Figaro',
#        'Oscar and Stanley', 'Ad guy 1', 'Ad guy 2', 'David Wallace',
#        'Andy, Creed, Kevin, Kelly, Darryl', 'Andy, Creed, Kevin, Kelly',
#        "Michael's Ad", 'Rolando', 'Ben', 'Security guard', 'Lester',
#        'Diane Kelly', 'Diane', 'Deposition Reporter', 'Council',
#        "Hunter's CD", 'Officer 1', 'Officer 2', 'Officer', 'Neighbor',
#        "Wendy's phone operator", 'Margaret', 'Coffee shop worker',
#        'Jan [on phone]', 'W.B. Jones', 'Paul Faust', 'Bill Cress', 'Paul',
#        'Michael/Dwight', 'Troy', 'Girl in Club', 'Tall Girl #1',
#        'All Girls', 'Tall Girl #2', 'Girl in 2nd club', 'Cleaning lady',
#        'Michael and Darryl', 'Phil Maguire', 'Phil', 'Justin',
#        'Angela and Dwight', 'Maguire', 'Woman on mic', 'Graphics guy',
#        'Brad', 'Air Force recruiter', 'Holly', 'Woman over speakerphone',
#        'Vance Refrigeration guy', 'Holy', 'Co-workers', 'Ronnie',
#        'Professor', 'Friend', 'JIM9334 [screen name]',
#        'Receptionitis15 [screen name]', 'JIM9334', 'Receptionitis15',
#        'Michael & Holly', 'Dight', 'Kendall', 'Michael [on phone]',
#        'Pam [on phone]', 'Man on phone', 'Hank [the security guard]',
#        'Guy in audience', 'Michael and Holly',
#        'Michael, Holly, and Darryl', 'Tom', 'Pete', 'Holly & Darryl',
#        'Holly & Michael', 'Mother', 'Alex', 'Customer', 'Kevin & Andy',
#        'Stanley & Phyllis', 'Stewardess', 'Beth', 'Concierge', 'Marie',
#        'Guy at table', 'Concierge Marie', 'Client', 'Dacvid Walalce',
#        'David Wallcve', 'Dacvid Wallace', 'Leo', 'Vance Refrigeration Guy',
#        'Police Officer 1', 'Police Officer 2', 'Guy buying doll',
#        'Rehab Nurse', 'Everyone watching', 'Entire Prince family',
#        'Prince Grandfather', 'Entire office', 'Jim ', 'Prince',
#        'Prince Granddaughter', 'Prince Grandmother', 'Prince Son',
#        'Phyllis and Creed', 'Lawyer', 'CPR trainer', 'CPR Trainer', 'Rose',
#        'Jessica Alba', 'Lily', 'Sam', 'Warehouse Michael', 'Julia', 'A.J.',
#        'Phone Salesman', 'Jim, Pam, Michael and Dwight',
#        'Blood Drive Worker', 'Blood Girl', 'Lynn', 'Blonde', 'Eric',
#        'Girl', 'Charles', 'Stephanie', 'Employees', 'Isaac',
#        'Angela and Kelly', 'Supervisor', 'Michal', 'Nana', 'Chares',
#        'Old Woman', 'Erin', 'Dwight and Erin', 'Dwight and Andy',
#        'Michael, Pam & Ryan', 'Secretary', 'Automated phone voice',
#        'Mr. Schofield', 'Financial Guy', 'Ty', 'Jessica',
#        'Vance Refrigeration Guy 1', 'Vance Refrigeration Guy 2', 'VRG 1',
#        'VRG 2', 'Rolph', 'AJ', 'Man from Buffalo', 'Woman from Buffalo',
#        'Dwight & Andy', 'Female Intern', 'Female intern', 'Maurie',
#        'Dwight, Jim & Pam', 'Jim & Pam', 'Megan', 'Gwenneth',
#        'Front Desk Clerk', 'Mr. Halpert', 'Mema', 'Mr. Beesly',
#        'Little Girl', 'Penny', 'Isabel', 'Hotel Employee', 'Hotel Manager',
#        "Pam's mom", 'Tom Halpert', 'Pete Halpert', 'Tom and Pete',
#        "Pam's dad", 'Grotti', 'Andy and Dwight', 'Credit card rep', 'Rep',
#        'Various', 'Keena Gifford', 'Helene', "David Wallace's Secretary",
#        'Voice on CD player', 'Limo Driver', 'Laurie', 'Registrar',
#        'Security', 'Woman in line', 'Man in line', 'Shareholder',
#        'Female Shareholder', 'Second Shareholder', 'Third Shareholder',
#        'Fourth Shareholder', "O'Keefe", 'Mikela', 'Students', 'Teacher',
#        'Lefevre', 'Zion', 'Deliveryman', 'Michael and Erin', 'Daryl',
#        'Office', 'Kelly and Erin', 'Matt', 'Computron', 'Fake Stanley',
#        'Gabe', 'Andy & Erin', 'Christian Slater', 'Jo Bennett', 'Jo',
#        'Jerry', 'Teddy Wallace', 'Mrs. Wallace', 'Teddy',
#        'Dwight, Jim and Michael', 'Policeman', 'Hospital employee',
#        "(Pam's mom) Heleen", 'Kathy', 'Dale', 'Clark', 'Isabelle', 'D',
#        'Warehouse guy 1', 'Warehouse guy 2', 'Reid', 'Night cleaning crew',
#        'Meredith, Creed, Oscar and Matt', 'Miichael', 'Julie', 'Hide',
#        'Bar Manager', 'Bouncer', 'Girl at table', 'Cookie Monster',
#        'Dwight.', "Hayworth's waiter", "Oscar's voice from the computer",
#        'Donna', 'Michael and Donna', 'Mihael', 'Old lady', 'Glen',
#        'Gym Instructor', 'Gym instructor', 'Dwight and Angela', 'Shane',
#        'Reporter', 'Realtor', 'Luke', 'Window treatment guy', 'Angel',
#        'Salesman', 'Usher', 'Shelby', 'Sweeney Todd', 'Mexican Man', 'Son',
#        'Nate', 'Employees except Dwight', 'Astrid', 'Carroll', 'Carrol',
#        'Danny', 'Steve', 'Darryl and Andy', 'Church congregation',
#        'Pastor', 'Female church member', 'Male church member',
#        'Female church member [to Michael]', 'Doug [church member]', 'Doug',
#        'Mee-Maw', 'MeeMaw', 'Carla', "Jim's Dad", 'Bus driver',
#        'Michael and Andy', 'Another guy', 'Radio', 'Cece', 'TV',
#        'Meridith', 'Robotic Voice', 'Ryan and Michael', 'Phyliss',
#        'Dwight & Nate', 'Passer-by', 'Pam ', 'Bass Player', 'Justine',
#        'Jada', 'Robert', 'Darrly', 'Member', 'Video Michael',
#        'Bookstore employee', 'DJ', 'David Brent', 'Older guy',
#        'Phyllis, Stanley, Dwight', 'Younger Guy', 'Older Woman',
#        'Professor Powell', 'Ryan and Kelly', 'Helen', 'Attendant',
#        'Hot Dog Guy', 'Cell Phone Sales Person', 'Boom Box',
#        'Andy and Erin', "Holly's Mom", "Holly's Dad", 'Deangelo',
#        'Deangelo/Michael', 'Denagelo', "Darryl's sister", 'DeAngelo',
#        'Audience', 'Together', 'Erin and Kelly', 'abe', 'Rory', 'DeAgnelo',
#        'Jordan', 'Dwight [on phone]', 'Mose [on phone]', 'All but Oscar',
#        'Darryl and Angela', 'Fred Henry', 'Fred', 'Warren Buffett',
#        'Warren', 'Robert California', 'Merv Bronte', 'Merv',
#        'Nellie Bertram', 'Nellie', 'Finger Lakes Guy',
#        'Pam as fourth-biggest client', 'Pam as ninth-biggest client',
#        'Darryl & Oscar', 'Tattoo Artist', 'Female Applicant',
#        'Male Applicant 1', 'Male Applicant 2', 'Gideon', 'Bruce',
#        'Dwight, Erin, Jim & Kevin', 'Walter', 'Ellen', 'Walter Jr',
#        'Andy & Walter', 'Walter & Walter Jr', "Erin's Cell Phone", 'Bert',
#        'Gabe/Kelly/Toby', 'Andy/Pam', 'Andy/Stanley', 'Val',
#        'Warehouse Crew', 'Cathy', 'Offscreen', 'Curtis', 'Drummer',
#        'Pam and Kelly', 'Old Man', 'Andy and Darryl', 'Darryl and Kevin',
#        'Park Ranger', 'Chelsea', 'Archivist', 'Narrator', 'Soldier',
#        'Amanda', 'Susan', 'Andy/Oscar', "Bob's Secretary",
#        'Mrs. California', 'Host', 'Queerenstein Bears', "Oscar's friend",
#        'Stu', 'Stonewall Host', 'Meredith & Kelly', 'Einsteins',
#        'Senator Lipton', 'Ernesto', 'Officer Foley',
#        'Andy, Darryl & Officer Foley', 'Saleswoman', 'Emergency Operator',
#        'Paramedic', 'Donna Muraski', 'Wally Amos', 'Angela/Pam', 'Brandon',
#        'Blogger', 'Blogger 2', 'Lady Blogger', 'Patty', 'Old Lady',
#        'Others', 'Elderly Woman', 'Irene', 'Alonzo', 'Glenn',
#        'Erin and Irene', 'Kevin & Meredith', 'Lauren', 'Party guests',
#        'Magician', 'Ravi', 'Robert & Creed', 'Wrangler', 'Senator', 'Vet',
#        'Harry', 'Mr. Ramish', 'Calvin', 'Off-camera', 'Rafe', 'Fake Jim',
#        'Voicemail', 'Nellie and Pam',
#        'Group: Dunder Mifflin!\nAndy: Andy Bernard presents: Summer Softball Epic Fails! [Kevin swings bat on screen, fart noise follows] Fail. [repeats] Fail',
#        '[repeats]\nAndy: Fail',
#        "[Clark and Pete are shown on screen]\nVideo Andy: Hey, I'm Pete, puberty is such a drag, man. And I'm Clark! I like to eat toilet paper. [Clark and Pete wave at camera] We fail! [Video shows memorial of Jerry",
#        'Phyllis, Kevin & Stanley', 'HCT', 'HCT Member #1', 'HCT Member #2',
#        'Broccoli Rob', 'Businessman #1', 'Businessman #2',
#        'Businessman #3', 'HCT Member #3', 'White', 'Boat Guy', 'Walt Jr.',
#        'Senator Liptop', 'Guys in breakroom', 'Business partner', 'Molly',
#        'Colin', 'Trevor', 'Julius Irving', 'New Instant Message',
#        'Suit Store Father', 'Athlead Employee', 'Dennis', 'Wade',
#        'Suit Store Son', 'Female Athlead Employee', '3rd Athlead Employee',
#        '4th Athlead Employee', 'Co-worker', 'Co-worker #2', 'Mr. Romanko',
#        'Dance Teacher', 'Ballerinas', 'Parent in Audience',
#        'Parent in audience #2', 'Parent in audience #1', 'Investor',
#        'Lonnie', 'Fast Food Worker', 'Drive Thru Customer', 'Brian',
#        'Cameraman', 'Rolf', 'Gabor', 'Zeke', 'Melvina', 'Wolf',
#        'Sensei Ira', 'Pam & Dwight', 'Frank', 'Party Announcer',
#        'Party Guest', 'Party Photographer', 'Party Waiter',
#        'Nail stylist 1', 'Nail stylist 2', 'Nail manager', 'Shirley',
#        'Athlead Coworker', 'Roger', 'Alice', "Oscar's Computer", 'Jeb',
#        'German Minister', 'Fannie', 'Henry', 'Esther', 'Aunt Shirley',
#        'Cameron', 'Promo Voice', 'Ryan Howard', 'Mr. Ruger',
#        'Promo Announcer', 'Ruger Sister 1', 'Salesmen', 'Ruger Sister 2',
#        'Angela & Oscar', 'Reporter #1', 'Reporter #2', 'Mrs. Davis',
#        'Phillip', 'Carla Fern', 'Director', 'Producer',
#        'Bob Vance, Vance Refrigeration', 'Production Assistant', 'Sensei',
#        'Philip', 'Check-in guy', 'Casey', 'Mark McGrath', 'Jim & Dwight',
#        'Camera Crew', 'People in line', 'Santigold', 'Aaron Rodgers',
#        'Clay Aiken', 'CameraMan', 'Malcolm', 'Casey Dean', 'Bill Hader',
#        'Seth Mayers', 'Dakota', 'Stripper', 'Jakey', 'Man 1', 'Woman 1',
#        'Woman 2', 'Man 2', 'Moderator', 'Man 3', 'Woman 3', 'Woman 4',
#        'Joan', 'Minister', 'Carol Stills'], dtype=object)

# %%
cleaned_data = raw_dataset.loc[raw_dataset['speaker'].isin(['Michael', 'Jim', 'Pam', 'Dwight', 'Jan', 'Michel', 'Todd Packer',
       'Phyllis', 'Stanley', 'Oscar', 'Angela', 'Kevin', 'Ryan', 'Roy', 'Toby', 'Kelly',
       'Meredith', 'Darryl', 'Packer'])]
cleaned_data
# Out:
#           id  season  episode  scene  \
# 0          1       1        1      1
# 1          2       1        1      1
# 2          3       1        1      1
# 3          4       1        1      1
# 4          5       1        1      1
# 5          6       1        1      2
# 6          7       1        1      3
# 7          8       1        1      3
# 8          9       1        1      3
# 9         10       1        1      3
# 10        11       1        1      3
# 11        12       1        1      3
# 12        13       1        1      3
# 13        14       1        1      3
# 14        15       1        1      3
# 15        16       1        1      4
# 16        17       1        1      5
# 17        18       1        1      6
# 18        19       1        1      7
# 19        20       1        1      7
# 20        21       1        1      7
# 21        22       1        1      7
# 22        23       1        1      7
# 23        24       1        1      7
# 24        25       1        1      7
# 25        26       1        1      7
# 26        27       1        1      7
# 27        28       1        1      7
# 28        29       1        1      7
# 29        30       1        1      8
# ...      ...     ...      ...    ...
# 59868  59869       9       23     98
# 59870  59871       9       23     99
# 59871  59872       9       23     99
# 59872  59873       9       23     99
# 59873  59874       9       23     99
# 59874  59875       9       23     99
# 59875  59876       9       23     99
# 59876  59877       9       23     99
# 59877  59878       9       23     99
# 59878  59879       9       23     99
# 59879  59880       9       23     99
# 59880  59881       9       23    100
# 59882  59883       9       23    101
# 59883  59884       9       23    101
# 59886  59887       9       23    103
# 59889  59890       9       23    106
# 59890  59891       9       23    107
# 59891  59892       9       23    107
# 59893  59894       9       23    107
# 59895  59896       9       23    108
# 59896  59897       9       23    108
# 59897  59898       9       23    108
# 59898  59899       9       23    108
# 59899  59900       9       23    108
# 59900  59901       9       23    108
# 59903  59904       9       23    111
# 59905  59906       9       23    113
# 59906  59907       9       23    114
# 59907  59908       9       23    115
# 59908  59909       9       23    116
#
#                                                line_text   speaker  deleted
# 0      All right Jim. Your quarterlies look very good...   Michael    False
# 1             Oh, I told you. I couldn't close it. So...       Jim    False
# 2      So you've come to the master for guidance? Is ...   Michael    False
# 3             Actually, you called me in here, but yeah.       Jim    False
# 4        All right. Well, let me show you how it's done.   Michael    False
# 5      [on the phone] Yes, I'd like to speak to your ...   Michael    False
# 6      I've, uh, I've been at Dunder Mifflin for 12 y...   Michael    False
# 7                                    Well. I don't know.       Pam    False
# 8      If you think she's cute now, you should have s...   Michael    False
# 9                                                  What?       Pam    False
# 10                                         Any messages?   Michael    False
# 11                                 Uh, yeah. Just a fax.       Pam    False
# 12     Oh! Pam, this is from Corporate. How many time...   Michael    False
# 13                                  You haven't told me.       Pam    False
# 14     It's called the wastepaper basket! Look at tha...   Michael    False
# 15     People say I am the best boss. They go, 'God w...   Michael    False
# 16     [singing] Shall I play for you? Pa rum pump um...    Dwight    False
# 17     My job is to speak to clients on the phone abo...       Jim    False
# 18                                              Whassup!   Michael    False
# 19         Whassup! I still love that after seven years.       Jim    False
# 20                                              Whassup!   Michael    False
# 21                                              Whassup!    Dwight    False
# 22                                           Whass...up!   Michael    False
# 23                                              Whassup.    Dwight    False
# 24                               [Strains, grunts] What?   Michael    False
# 25                                              Nothing.       Jim    False
# 26                         OK. All right. See you later.   Michael    False
# 27                                 All right. Take care.       Jim    False
# 28                                         Back to work.   Michael    False
# 29     [on her cell phone] Just before lunch. That wo...       Jan    False
# ...                                                  ...       ...      ...
# 59868                                        What is it?     Kevin    False
# 59870        I finally feel ready. Athlead is growing���       Pam    False
# 59871                                           Athleap.       Jim    False
# 59872  And Jim can jump back in without skipping a be...       Pam    False
# 59873  No, don���t say it. You���re fired! You���re b...    Dwight    False
# 59874        Dwight, come on. Don���t end on a bad note.       Jim    False
# 59875  Don���t be an idiot. It���s for the severance....    Dwight    False
# 59876                                     Thanks Dwight.       Pam    False
# 59877             Hey, and if you���re ever in Austin...       Jim    False
# 59878  Woah. Right. For what, the art? The music? The...    Dwight    False
# 59879                                       There it is.       Jim    False
# 59880  Do I get along with my co-workers? Well, first...    Dwight    False
# 59882                                           Oh, Yes!     Kevin    False
# 59883                           You did good. Real good.    Darryl    False
# 59886  You take something ordinary, like a piece of p...     Oscar    False
# 59889  Imagine going back and watching a tape of your...       Jim    False
# 59890  Hey, Jim, remember flonkerton when you did Off...   Phyllis    False
# 59891                                       Thanks Phyl.       Jim    False
# 59893                       Do you even have a mattress?    Angela    False
# 59895          Oscar. Oscar. [crying] I think I���m gay.     Kevin    False
# 59896                               Why do you say that?     Oscar    False
# 59897    [sniffles] It���s just that I���m so emotional.     Kevin    False
# 59898      Yeah, but you���re not gay. You���re not gay.     Oscar    False
# 59899                        No, but maybe the reason���     Kevin    False
# 59900                                  You���re not gay.     Oscar    False
# 59903  Everyday when I came into work, all I wanted t...    Darryl    False
# 59905  I just feel lucky that I got a chance to share...  Meredith    False
# 59906  I���m happy that this was all filmed so I can ...   Phyllis    False
# 59907  I sold paper at this company for 12 years. My ...       Jim    False
# 59908  I thought it was weird when you picked us to m...       Pam    False
#
# [45077 rows x 7 columns]

# %%
episode_data = cleaned_data.groupby(['season', 'episode', 'speaker', 'line_text']).sum()
episode_data
# Out:
#                                                                               id  \
# season episode speaker line_text
# 1      1       Angela  I bet it's gonna be me. Probably gonna be me.          68
#                        I have a lot of cat figurines on my desk. I thi...    253
#                        My name is Angela and um, I'm in charge of the ...    246
#                        Not very worried about downsizing right now. Be...    251
#                        Oscar, how do I describe him. He's like a stapl...    248
#                Dwight  Damn it! Jim!                                         147
#                        Downsizing?                                            95
#                        Downsizing? I have no problem with that. I have...     96
#                        Dwight Schrute, Assistant Regional Manager.           142
#                        Dwight Schrute. My father's name, also Dwight S...    230
#                        Go ahead.                                             117
#                        He put my stuff in Jell-O again.                      149
#                        I understand. It's in a blind spot because I'm ...    268
#                        I'm Assistant Regional Manager. I should know f...    108
#                        I'm doing my job.                                     269
#                        I'm sorry it makes me nervous.                        266
#                        It's OK here, but people sometimes take advanta...    152
#                        It's always you. Are you going to discipline hi...    158
#                        It's overlapping. It's all spilling over the ed...     90
#                        Just clearing my desk. I can't concentrate.            88
#                        New engine, new suspension, I got a respray. I'...    146
#                        OK you know what, you can be a witness. [points...    156
#                        OK, that's great. I guess what I'm most concern...    166
#                        OK, um, can you just tell me please? Just tell ...    110
#                        OK. You tell 'em. With my permission. Permissio...    115
#                        On his mother's grave.                                125
#                        Pam, information is power.                            134
#                        People respond to the human touch and that's wh...    238
#                        Please, OK? Do you want me to tell 'em?               113
#                        Safety violation. I could fall and pierce an or...     93
# ...                                                                          ...
# 9      23      Ryan    Kelly, you���re here.                               59719
#                        No Kelly, he���s no named after a hip-hop artis...  59729
#                        No, this little guy is mine.                        59723
#                        Ravi? Ravi? Drake has a bit of a rash. And he��...  59762
#                        Say ���hi���, Drake.                                59725
#                        So I was dating this girl, and one day, she wen...  59724
#                        Thank you Ravi. Thank you so much. This is grea...  59769
#                        We���re gonna be together forever.                  59786
#                        Yeah.                                               59727
#                Stanley Ah, I���ve been looking forward to this day sin...  59396
#                        Hey guys.                                           59657
#                        I guess this was work being filmed nonstop for ...  59665
#                        I had to pledge $50 to my local PBS station jus...  59846
#                        I missed you too.                                   59782
#                        Oh, great.                                          59660
#                        Okay, I need a drink.                               59854
#                        Yes, I���m living in Florida now. Little town c...  59661
#                Toby    Anyone can follow a Twitter feed. Wanna share a...  59475
#                        Good luck.                                          59801
#                        Hello! [laughing] Hello!                            59467
#                        Hi! [goes to hug Nellie]                            59469
#                        Oh, I don���t know. I might turn in early.          59806
#                        Oh, no, no. no. My plane just got in. From New ...  59473
#                        Oh. [laughs nervously]                              59471
#                        Yeah. I���ll stop by.                               59811
#                        Yeah. Yeah, I don���t think���                      59415
#                        Yes.                                                59690
#                        [alone in cab} After Dwight fired me, I moved t...  59476
#                        [dancing with Pam] [sobbing]                        59778
#                        [sobbing] It���s everything.                        59780
#
#                                                                            scene  \
# season episode speaker line_text
# 1      1       Angela  I bet it's gonna be me. Probably gonna be me.          14
#                        I have a lot of cat figurines on my desk. I thi...     46
#                        My name is Angela and um, I'm in charge of the ...     46
#                        Not very worried about downsizing right now. Be...     46
#                        Oscar, how do I describe him. He's like a stapl...     46
#                Dwight  Damn it! Jim!                                          30
#                        Downsizing?                                            19
#                        Downsizing? I have no problem with that. I have...     20
#                        Dwight Schrute, Assistant Regional Manager.            29
#                        Dwight Schrute. My father's name, also Dwight S...     40
#                        Go ahead.                                              24
#                        He put my stuff in Jell-O again.                       30
#                        I understand. It's in a blind spot because I'm ...     50
#                        I'm Assistant Regional Manager. I should know f...     24
#                        I'm doing my job.                                      50
#                        I'm sorry it makes me nervous.                         50
#                        It's OK here, but people sometimes take advanta...     31
#                        It's always you. Are you going to discipline hi...     32
#                        It's overlapping. It's all spilling over the ed...     19
#                        Just clearing my desk. I can't concentrate.            19
#                        New engine, new suspension, I got a respray. I'...     29
#                        OK you know what, you can be a witness. [points...     32
#                        OK, that's great. I guess what I'm most concern...     32
#                        OK, um, can you just tell me please? Just tell ...     24
#                        OK. You tell 'em. With my permission. Permissio...     24
#                        On his mother's grave.                                 26
#                        Pam, information is power.                             26
#                        People respond to the human touch and that's wh...     42
#                        Please, OK? Do you want me to tell 'em?                24
#                        Safety violation. I could fall and pierce an or...     19
# ...                                                                          ...
# 9      23      Ryan    Kelly, you���re here.                                  64
#                        No Kelly, he���s no named after a hip-hop artis...     66
#                        No, this little guy is mine.                           64
#                        Ravi? Ravi? Drake has a bit of a rash. And he��...     75
#                        Say ���hi���, Drake.                                   66
#                        So I was dating this girl, and one day, she wen...     65
#                        Thank you Ravi. Thank you so much. This is grea...     75
#                        We���re gonna be together forever.                     81
#                        Yeah.                                                  66
#                Stanley Ah, I���ve been looking forward to this day sin...      3
#                        Hey guys.                                              48
#                        I guess this was work being filmed nonstop for ...     50
#                        I had to pledge $50 to my local PBS station jus...     88
#                        I missed you too.                                      79
#                        Oh, great.                                             48
#                        Okay, I need a drink.                                  93
#                        Yes, I���m living in Florida now. Little town c...     49
#                Toby    Anyone can follow a Twitter feed. Wanna share a...     22
#                        Good luck.                                             85
#                        Hello! [laughing] Hello!                               22
#                        Hi! [goes to hug Nellie]                               22
#                        Oh, I don���t know. I might turn in early.             85
#                        Oh, no, no. no. My plane just got in. From New ...     22
#                        Oh. [laughs nervously]                                 22
#                        Yeah. I���ll stop by.                                  85
#                        Yeah. Yeah, I don���t think���                          3
#                        Yes.                                                   58
#                        [alone in cab} After Dwight fired me, I moved t...     23
#                        [dancing with Pam] [sobbing]                           78
#                        [sobbing] It���s everything.                           78
#
#                                                                            deleted
# season episode speaker line_text
# 1      1       Angela  I bet it's gonna be me. Probably gonna be me.           0.0
#                        I have a lot of cat figurines on my desk. I thi...      1.0
#                        My name is Angela and um, I'm in charge of the ...      1.0
#                        Not very worried about downsizing right now. Be...      1.0
#                        Oscar, how do I describe him. He's like a stapl...      1.0
#                Dwight  Damn it! Jim!                                           0.0
#                        Downsizing?                                             0.0
#                        Downsizing? I have no problem with that. I have...      0.0
#                        Dwight Schrute, Assistant Regional Manager.             0.0
#                        Dwight Schrute. My father's name, also Dwight S...      1.0
#                        Go ahead.                                               0.0
#                        He put my stuff in Jell-O again.                        0.0
#                        I understand. It's in a blind spot because I'm ...      1.0
#                        I'm Assistant Regional Manager. I should know f...      0.0
#                        I'm doing my job.                                       1.0
#                        I'm sorry it makes me nervous.                          1.0
#                        It's OK here, but people sometimes take advanta...      0.0
#                        It's always you. Are you going to discipline hi...      0.0
#                        It's overlapping. It's all spilling over the ed...      0.0
#                        Just clearing my desk. I can't concentrate.             0.0
#                        New engine, new suspension, I got a respray. I'...      0.0
#                        OK you know what, you can be a witness. [points...      0.0
#                        OK, that's great. I guess what I'm most concern...      0.0
#                        OK, um, can you just tell me please? Just tell ...      0.0
#                        OK. You tell 'em. With my permission. Permissio...      0.0
#                        On his mother's grave.                                  0.0
#                        Pam, information is power.                              0.0
#                        People respond to the human touch and that's wh...      1.0
#                        Please, OK? Do you want me to tell 'em?                 0.0
#                        Safety violation. I could fall and pierce an or...      0.0
# ...                                                                            ...
# 9      23      Ryan    Kelly, you���re here.                                   0.0
#                        No Kelly, he���s no named after a hip-hop artis...      0.0
#                        No, this little guy is mine.                            0.0
#                        Ravi? Ravi? Drake has a bit of a rash. And he��...      0.0
#                        Say ���hi���, Drake.                                    0.0
#                        So I was dating this girl, and one day, she wen...      0.0
#                        Thank you Ravi. Thank you so much. This is grea...      0.0
#                        We���re gonna be together forever.                      0.0
#                        Yeah.                                                   0.0
#                Stanley Ah, I���ve been looking forward to this day sin...      0.0
#                        Hey guys.                                               0.0
#                        I guess this was work being filmed nonstop for ...      0.0
#                        I had to pledge $50 to my local PBS station jus...      0.0
#                        I missed you too.                                       0.0
#                        Oh, great.                                              0.0
#                        Okay, I need a drink.                                   0.0
#                        Yes, I���m living in Florida now. Little town c...      0.0
#                Toby    Anyone can follow a Twitter feed. Wanna share a...      0.0
#                        Good luck.                                              0.0
#                        Hello! [laughing] Hello!                                0.0
#                        Hi! [goes to hug Nellie]                                0.0
#                        Oh, I don���t know. I might turn in early.              0.0
#                        Oh, no, no. no. My plane just got in. From New ...      0.0
#                        Oh. [laughs nervously]                                  0.0
#                        Yeah. I���ll stop by.                                   0.0
#                        Yeah. Yeah, I don���t think���                          0.0
#                        Yes.                                                    0.0
#                        [alone in cab} After Dwight fired me, I moved t...      0.0
#                        [dancing with Pam] [sobbing]                            0.0
#                        [sobbing] It���s everything.                            0.0
#
# [44416 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'line_text'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-4bf16b30455e> in <module>()
# ----> 1 episode_data.loc[episode_data['line_text']]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'line_text'

# %%
d = []

for i in np.arange(len(episode_data['speaker'])):
    lines = episode_data['line_text'][i].split()
    e = {x : line.count(x) for x in line}
    e['CLASS'] = raw_dataset['speaker'][i]
    d.append(e)
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'speaker'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-341d1f445267> in <module>()
#       1 d = []
#       2
# ----> 3 for i in np.arange(len(episode_data['speaker'])):
#       4     line = episode_data['line_text'][i].split()
#       5     e = {x : line.count(x) for x in line}
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'speaker'
